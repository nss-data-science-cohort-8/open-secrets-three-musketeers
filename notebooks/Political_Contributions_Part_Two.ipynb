# %%
import pandas as pd
import os

# %%
os.chdir('..')
print(f'current working directory is {os.getcwd()}')
# Out:
# current working directory is /Users/graciepiantek/Documents/NSS_Projects/open-secrets-three-musketeers

# %%
Pol_Cont_df = pd.read_csv('../open-secrets-three-musketeers/data/full_df.csv')

# %%
Pol_Cont_df.isna().sum()
# Out:
# cid                  0
# FirstLastP           0
# Rcpts                0
# Spent                0
# PACs                 0
# Indivs               0
# Cand                 0
# Other                0
# EndCash              0
# LgIndivs             0
# SmIndivs             0
# enddate            363
# ReleaseDate          0
# VotePercent          0
# Result               0
# CRPICO               0
# State                0
# IncCID            1264
# Incumbent         1264
# primarydate          0
# DistIDCurr         363
# capeye               0
# sort                 0
# SmLgIndivsNote       0
# District             0
# State_Abv            0
# dtype: int64

# %%
Pol_Cont_df.shape
# Out:
# (1264, 26)

# %%
Pol_Cont_df['enddate'].unique() == 'nan'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
Pol_Cont_df['enddate'].nunique()
# Out:
# 47

# %%
Pol_Cont_df['enddate'] == 'nan'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1259    False
# 1260    False
# 1261    False
# 1262    False
# 1263    False
# Name: enddate, Length: 1264, dtype: bool

# %%
Pol_Cont_df['enddate']! == 'NaN'
# Out:
#   Cell In[26], line 1
#     Pol_Cont_df['enddate']! == 'NaN'
#                           ^
# SyntaxError: invalid syntax

# %%
Pol_Cont_df['enddate']
# Out:
# 0       2020-12-31 00:00:00 +0000
# 1       2020-12-31 00:00:00 +0000
# 2       2020-12-31 00:00:00 +0000
# 3       2020-12-31 00:00:00 +0000
# 4                             NaN
#                   ...
# 1259    2020-12-31 00:00:00 +0000
# 1260    2020-12-31 00:00:00 +0000
# 1261                          NaN
# 1262                          NaN
# 1263                          NaN
# Name: enddate, Length: 1264, dtype: object

# %%
Pol_Cont_df
# Out:
#             cid               FirstLastP       Rcpts       Spent        PACs  \
# 0     N00044245           Jerry Carl (R)  1971321.50  1859348.91   387000.00
# 1     N00044750       James Averhart (D)    80094.95    78973.24        0.00
# 2     N00041295          Barry Moore (R)   650806.75   669367.70   230281.65
# 3     N00045944  Phyllis Harvey-Hall (D)    56049.68    55988.07     2032.00
# 4     N00045631            John Page (L)        0.00        0.00        0.00
# ...         ...                      ...         ...         ...         ...
# 1259  N00035504           Liz Cheney (R)  3003883.34  3060166.78  1292490.00
# 1260  N00047272   Lynnette Grey Bull (D)   134597.32   132234.75     2800.00
# 1261  N00047207         Zoilo Adalia (3)        0.00        0.00        0.00
# 1262  N00035139     Richard Brubaker (L)        0.00        0.00        0.00
# 1263  N00047495          Jeff Haggit (3)        0.00        0.00        0.00
#
# ...
